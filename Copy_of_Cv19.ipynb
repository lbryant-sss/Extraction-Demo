# %% [markdown]
# <a href="https://colab.research.google.com/github/lbryant-sss/Extraction-Demo/blob/main/Copy_of_Cv19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import json
import pprint
url = ('https://api.covid19api.com/summary')
print(url)
make = requests.get(url)
print(f"Response returned {make.status_code} :'{make.reason}'")
data = make.json()
payload = pprint.PrettyPrinter(indent=1)
payload.pprint(data)
type(data)
# Out:
# https://api.covid19api.com/summary
# Response returned 200 :'OK'
# {'Countries': [{'Country': 'Afghanistan',
#                 'CountryCode': 'AF',
#                 'Date': '2020-11-21T17:55:50Z',
#                 'NewConfirmed': 215,
#                 'NewDeaths': 11,
#                 'NewRecovered': 20,
#                 'Premium': {},
#                 'Slug': 'afghanistan',
#                 'TotalConfirmed': 44443,
#                 'TotalDeaths': 1661,
#                 'TotalRecovered': 35370},
#                {'Country': 'Albania',
#                 'CountryCode': 'AL',
#                 'Date': '2020-11-21T17:55:50Z',
#                 'NewConfirmed': 836,
#                 'NewDeaths': 15,
#                 'NewRecovered': 490,
#                 'Premium': {},
#                 'Slug': 'albania',
#                 'TotalConfirmed': 31459,
#                 'TotalDeaths': 672,
#                 'TotalRecovered': 15055},
#                {'Country': 'Algeria',
# ...

# %%
df = pd.DataFrame(countries)
df
# Out:
#             Country CountryCode  ...                  Date  Premium
# 0       Afghanistan          AF  ...  2020-11-21T17:55:50Z       {}
# 1           Albania          AL  ...  2020-11-21T17:55:50Z       {}
# 2           Algeria          DZ  ...  2020-11-21T17:55:50Z       {}
# 3           Andorra          AD  ...  2020-11-21T17:55:50Z       {}
# 4            Angola          AO  ...  2020-11-21T17:55:50Z       {}
# ..              ...         ...  ...                   ...      ...
# 186        Viet Nam          VN  ...  2020-11-21T17:55:50Z       {}
# 187  Western Sahara          EH  ...  2020-11-21T17:55:50Z       {}
# 188           Yemen          YE  ...  2020-11-21T17:55:50Z       {}
# 189          Zambia          ZM  ...  2020-11-21T17:55:50Z       {}
# 190        Zimbabwe          ZW  ...  2020-11-21T17:55:50Z       {}
#
# [191 rows x 11 columns]

# %%
y = df['TotalConfirmed']
x = df['TotalDeaths']
z = df['TotalRecovered']

# %%
import matplotlib.pyplot as plt

# %%
plt.show()
plt.xlabel('TotalConfirmed');
plt.ylabel('TotalDeaths')
plt.scatter(x,y)
